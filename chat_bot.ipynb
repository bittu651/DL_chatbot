# %%
import json 
import time
import numpy as np 
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Embedding, GlobalAveragePooling1D
from keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences
from sklearn.preprocessing import LabelEncoder
from keras.preprocessing.text import Tokenizer
from sklearn.preprocessing import LabelEncoder

# %%
with open('intents.json') as file:
    data = json.load(file)
    
training_sentences = []
training_labels = []
labels = []
responses = []


for intent in data['intents']:
    for pattern in intent['patterns']:
        training_sentences.append(pattern)
        training_labels.append(intent['tag'])
    responses.append(intent['responses'])
    
    if intent['tag'] not in labels:
        labels.append(intent['tag'])
        
num_classes = len(labels)

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(training_sentences)

training_sequences = tokenizer.texts_to_sequences(training_sentences)

label_encoder = LabelEncoder()
label_encoder.fit(training_labels)
training_labels = label_encoder.transform(training_labels)

# %%
vocab_size = 1000
embedding_dim = 16
max_len = 20
oov_token = "<OOV>"

tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_token)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(training_sentences)
padded_sequences = pad_sequences(sequences, truncating='post', maxlen=max_len)

# %%
model = Sequential()
model.add(Embedding(vocab_size, embedding_dim, input_length=max_len))
model.add(GlobalAveragePooling1D())
model.add(Dense(16, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', 
              optimizer='adam', metrics=['accuracy'])

model.summary()
epochs = 500
history = model.fit(padded_sequences, np.array(training_labels), epochs=epochs)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_2 (Embedding)     (None, 20, 16)            16000
#
#  global_average_pooling1d_2   (None, 16)               0
#  (GlobalAveragePooling1D)
#
#  dense_6 (Dense)             (None, 16)                272
#
#  dense_7 (Dense)             (None, 16)                272
#
#  dense_8 (Dense)             (None, 8)                 136
#
# ...
# Total params: 16,680
# Trainable params: 16,680
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 2/2 [==============================] - 1s 6ms/step - loss: 2.0790 - accuracy: 0.2121
# Epoch 2/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.0776 - accuracy: 0.2424
# Epoch 3/500
# 2/2 [==============================] - 0s 9ms/step - loss: 2.0769 - accuracy: 0.2121
# Epoch 4/500
# ...

# %%
model.save("chat_model")

import pickle
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
with open('label_encoder.pickle', 'wb') as ecn_file:
    pickle.dump(label_encoder, ecn_file, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: chat_model\assets
# INFO:tensorflow:Assets written to: chat_model\assets

# %%
# define a function to preprocess new data
def preprocess_new_data(new_data):
    # preprocess the new data in the same way as your original training data
    # ...
    return new_sequences, new_labels

# define a function to update the model with new data
def update_model(model, new_data):
    # preprocess the new data
    new_sequences, new_labels = preprocess_new_data(new_data)
    
    # update the model by calling its fit method with the new data
    model.fit(new_sequences, new_labels, epochs=1)

# define a function to retrieve new data from the database or log file
def get_new_data():
    # retrieve the new data from the database or log file
    # ...
    return new_data

# periodically update the model with new data
while True:
    # wait for a specified amount of time
    update_interval = 60
    time.sleep(update_interval)
    
    # retrieve the new data
    new_data = get_new_data()
    
    # update the model with the new data
    update_model(model, new_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 28
#      25 time.sleep(update_interval)
#      27 # retrieve the new data
# ---> 28 new_data = get_new_data()
#      30 # update the model with the new data
#      31 update_model(model, new_data)
#
# Cell In[17], line 19, in get_new_data()
#      16 def get_new_data():
#      17     # retrieve the new data from the database or log file
#      18     # ...
# ---> 19     return new_data
#
# NameError: name 'new_data' is not defined
